# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

from External.plotting import plot_points, plot_graph
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
plt.style.use('standard.mplstyle')

# %%
CA_to_CC = np.load("/net/hcihome/storage/flernst/Data/eth_CC/CA_to_CC.npy")
PC_to_CC = np.load("/net/hcihome/storage/flernst/Data/eth_CC/PC_to_CC.npy")
DTAE_embedding = pd.read_csv("~/Data/eth/embedding_own.csv",header=None).to_numpy()[CA_to_CC]
labels = pd.read_csv("~/Data/eth_reduced/obs.csv",header=0)[PC_to_CC]
labels = labels["annot"].to_numpy()

# %%
fig, ax2 = plt.subplots(1,1, figsize=(24,24))

plot_points(DTAE_embedding, "Own Embedding", ax2, labels)

plt.ylim(-100,75)
plt.xlim(-100, 75)
plt.tight_layout()
plt.savefig("./Output/Images/"+"eth_CC"+"-Own-Embedding"+".png")

plt.show()

# %%
DTAE_embedding = pd.read_csv("~/Data/pancreas/embedding_own.csv",header=None).to_numpy()

labels = pd.read_csv("~/Data/pancreas/obs.csv",header=0)

labels = labels["clusters_fig6_broad_final"].to_numpy()

# %%
fig, ax2 = plt.subplots(1,1, figsize=(24,24))

plot_points(DTAE_embedding, "Own Embedding", ax2, labels)

# plt.ylim(-100,75)
# plt.xlim(-100, 75)
plt.tight_layout()
plt.savefig("./Output/Images/"+"pancreas_full"+"-Own-Embedding"+".png")

plt.show()
